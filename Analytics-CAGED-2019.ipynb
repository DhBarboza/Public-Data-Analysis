# %%
import pandas as pd

# %%
db = pd.read_csv('analise.csv', delimiter=';', error_bad_lines=False)
# Out:
# c:\users\douglas henrique\appdata\local\programs\python\python39\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (32,33,34,35,36,37,38,39) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
db.head(10)
# Out:
#   ,Admitidos/Desligados  Compet�ncia Declarada  Munic�pio  Ano Declarado  \
# 0                 0,"01                 201901     510267           2019
# 1                 1,"01                 201901     510805           2019
# 2                 2,"01                 201901     510263           2019
# 3                 3,"01                 201901     510267           2019
# 4                 4,"01                 201901     510525           2019
# 5                 5,"01                 201901     510525           2019
# 6                 6,"01                 201901     510735           2019
# 7                 7,"01                 201901     510735           2019
# 8                 8,"01                 201901     510370           2019
# 9                 9,"01                 201901     510626           2019
#
#    CBO 2002 Ocupa��o  CNAE 1.0 Classe  CNAE 2.0,Classe  CNAE 2.0 Subclas  \
# 0             413110             1155             1156            115600
# ...

# %%
db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2616053 entries, 0 to 2616052
# Data columns (total 42 columns):
#  #   Column                   Dtype
# ---  ------                   -----
#  0   ,Admitidos/Desligados    object
#  1   Compet�ncia Declarada    int64
#  2   Munic�pio                int64
#  3   Ano Declarado            int64
#  4   CBO 2002 Ocupa��o        int64
#  5   CNAE 1.0 Classe          int64
#  6   CNAE 2.0,Classe          int64
#  7   CNAE 2.0 Subclas         int64
#  8   Faixa Empr In�cio Jan    int64
#  9   Grau Instru��o           int64
#  10  Qtd Hora,Contrat         int64
#  11  IBGE,Subsetor            int64
#  12  Idade                    int64
#  13  Ind,Aprendiz             int64
#  14  Ind,Portador,Defic       int64
#  15  Ra�a,Cor                 int64
#  16  Sal�rio,Mensal           object
#  17  Saldo,Mov                int64
#  18  Sexo                     int64
#  19  Tempo,Emprego            object
#  20  Tipo,Estab               int64
# ...
